# %%
import json
# function to load the data
def load_data(filename):
    with open(filename,"r") as file:
        data = json.load(file)
    return data 
data = load_data("data.json")
# function to output data
def user_data(data):
    print("User name and it's connection:")
    for user in data['users']:
        print(f"{user['name']} - id: {user['id']} is friends with {user['friends']} and liked pages are {user['liked_pages']}")
    print("\nPages:")
    for page in data['pages']:
        print(f"{page['id']} - {page['name']}")
user_data(data)
# Out:
# User name and it's connection:
# Amit - id: 1 is friends with [2, 3] and liked pages are [101]
# Priya - id: 2 is friends with [1, 4] and liked pages are [102]
# Rahul - id: 3 is friends with [1] and liked pages are [101, 103]
# Sara - id: 4 is friends with [2] and liked pages are [104]
#
# Pages:
# 101 - Python Developers
# 102 - Data Science Enthusiasts
# 103 - AI & ML Community
# 104 - Web Dev Hub

# %%
import json
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data
data = load_data("data.json")
print(data)
def output_data(data):
    for user in data['users']:
        print(f"{user['name']} - id: {user['id']} is friends with 
        {user['friends']} and liked pages are {user['liked_pages']}")
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}, {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}, {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]}, {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}], 'pages': [{'id': 101, 'name': 'Python Developers'}, {'id': 102, 'name': 'Data Science Enthusiasts'}, {'id': 103, 'name': 'AI & ML Community'}, {'id': 104, 'name': 'Web Dev Hub'}]}
